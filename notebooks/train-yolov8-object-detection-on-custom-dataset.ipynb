# %% [markdown]
# <a href="https://colab.research.google.com/github/SandeepaPethangoda/MOBILE_NET_SSD_CUSTOM/blob/main/notebooks/train-yolov8-object-detection-on-custom-dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [![Roboflow Notebooks](https://media.roboflow.com/notebooks/template/bannertest2-2.png?ik-sdk-version=javascript-1.4.3&updatedAt=1672932710194)](https://github.com/roboflow/notebooks)
#
# # How to Train YOLOv8 Object Detection on a Custom Dataset
#
# ---
#
# [![Roboflow](https://raw.githubusercontent.com/roboflow-ai/notebooks/main/assets/badges/roboflow-blogpost.svg)](https://blog.roboflow.com/how-to-train-yolov8-on-a-custom-dataset)
# [![YouTube](https://badges.aleen42.com/src/youtube.svg)](https://youtu.be/wuZtUMEiKWY)
# [![GitHub](https://badges.aleen42.com/src/github.svg)](https://github.com/ultralytics/ultralytics)
#
# Ultralytics YOLOv8 is a popular version of the YOLO (You Only Look Once) object detection and image segmentation model developed by Ultralytics. The YOLOv8 model is designed to be fast, accurate, and easy to use, making it an excellent choice for a wide range of object detection and image segmentation tasks. It can be trained on large datasets and is capable of running on a variety of hardware platforms, from CPUs to GPUs.
#
# ## Disclaimer
#
# If you notice that our notebook behaves incorrectly - especially if you experience errors that prevent you from going through the tutorial - don't hesitate! Let us know and open an [issue](https://github.com/roboflow/notebooks/issues) on the Roboflow Notebooks repository.
#
# ## Accompanying Blog Post
#
# We recommend that you follow along in this notebook while reading the accompanying [Blog Post](https://blog.roboflow.com/how-to-train-yolov8-on-a-custom-dataset/).
#
# ## Pro Tip: Use GPU Acceleration
#
# If you are running this notebook in Google Colab, navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `GPU`, and then click `Save`. This will ensure your notebook uses a GPU, which will significantly speed up model training times.
#
# ## Steps in this Tutorial
#
# In this tutorial, we are going to cover:
#
# - Before you start
# - Install YOLOv8
# - CLI Basics
# - Inference with Pre-trained COCO Model
# - Roboflow Universe
# - Preparing a custom dataset
# - Custom Training
# - Validate Custom Model
# - Inference with Custom Model
#
# **Let's begin!**

# %% [markdown]
# ## Before you start
#
# Let's make sure that we have access to GPU. We can use `nvidia-smi` command to do that. In case of any problems navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `GPU`, and then click `Save`.

# %%
# !nvidia-smi

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %% [markdown]
# ## Install YOLOv8
#
# YOLOv8 can be installed in two ways - from the source and via pip. This is because it is the first iteration of YOLO to have an official package.

# %%
# Pip install method (recommended)

# !pip install ultralytics==8.2.103 -q

from IPython import display
display.clear_output()

# prevent ultralytics from tracking your activity
# !yolo settings sync=False

import ultralytics
ultralytics.checks()

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %% [markdown]
# ## CLI Basics

# %% [markdown]
# If you want to train, validate or run inference on models and don't need to make any modifications to the code, using YOLO command line interface is the easiest way to get started. Read more about CLI in [Ultralytics YOLO Docs](https://docs.ultralytics.com/usage/cli/).
#
# ```
# yolo task=detect    mode=train    model=yolov8n.yaml      args...
#           classify       predict        yolov8n-cls.yaml  args...
#           segment        val            yolov8n-seg.yaml  args...
#                          export         yolov8n.pt        format=onnx  args...
# ```

# %% [markdown]
# ## Inference with Pre-trained COCO Model

# %% [markdown]
# ### 💻 CLI

# %% [markdown]
# `yolo mode=predict` runs YOLOv8 inference on a variety of sources, downloading models automatically from the latest YOLOv8 release, and saving results to `runs/predict`.

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model=/content/runs/detect/train4/weights/best.pt conf=0.25 source=/content/resources/vid1.mp4 save=True
# Out:
# /content
# Ultralytics YOLOv8.2.103 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 168 layers, 11,125,971 parameters, 0 gradients, 28.4 GFLOPs
#
# video 1/1 (frame 1/285) /content/resources/vid1.mp4: 800x480 2 plates, 42.0ms
# video 1/1 (frame 2/285) /content/resources/vid1.mp4: 800x480 2 plates, 15.6ms
# video 1/1 (frame 3/285) /content/resources/vid1.mp4: 800x480 3 plates, 15.6ms
# video 1/1 (frame 4/285) /content/resources/vid1.mp4: 800x480 3 plates, 15.6ms
# video 1/1 (frame 5/285) /content/resources/vid1.mp4: 800x480 3 plates, 15.6ms
# video 1/1 (frame 6/285) /content/resources/vid1.mp4: 800x480 3 plates, 15.6ms
# video 1/1 (frame 7/285) /content/resources/vid1.mp4: 800x480 5 plates, 15.7ms
# video 1/1 (frame 8/285) /content/resources/vid1.mp4: 800x480 6 plates, 15.6ms
# video 1/1 (frame 9/285) /content/resources/vid1.mp4: 800x480 5 plates, 15.6ms
# video 1/1 (frame 10/285) /content/resources/vid1.mp4: 800x480 7 plates, 15.6ms
# video 1/1 (frame 11/285) /content/resources/vid1.mp4: 800x480 6 plates, 15.6ms
# video 1/1 (frame 12/285) /content/resources/vid1.mp4: 800x480 6 plates, 15.6ms
# video 1/1 (frame 13/285) /content/resources/vid1.mp4: 800x480 6 plates, 15.6ms
# video 1/1 (frame 14/285) /content/resources/vid1.mp4: 800x480 5 plates, 15.6ms
# video 1/1 (frame 15/285) /content/resources/vid1.mp4: 800x480 4 plates, 15.6ms
# video 1/1 (frame 16/285) /content/resources/vid1.mp4: 800x480 4 plates, 15.6ms
# video 1/1 (frame 17/285) /content/resources/vid1.mp4: 800x480 6 plates, 15.6ms
# video 1/1 (frame 18/285) /content/resources/vid1.mp4: 800x480 7 plates, 15.6ms
# video 1/1 (frame 19/285) /content/resources/vid1.mp4: 800x480 9 plates, 15.6ms
# video 1/1 (frame 20/285) /content/resources/vid1.mp4: 800x480 11 plates, 15.6ms
# video 1/1 (frame 21/285) /content/resources/vid1.mp4: 800x480 11 plates, 15.6ms
# video 1/1 (frame 22/285) /content/resources/vid1.mp4: 800x480 12 plates, 15.4ms
# video 1/1 (frame 23/285) /content/resources/vid1.mp4: 800x480 11 plates, 15.2ms
# video 1/1 (frame 24/285) /content/resources/vid1.mp4: 800x480 10 plates, 15.3ms
# video 1/1 (frame 25/285) /content/resources/vid1.mp4: 800x480 9 plates, 15.3ms
# video 1/1 (frame 26/285) /content/resources/vid1.mp4: 800x480 11 plates, 15.2ms
# video 1/1 (frame 27/285) /content/resources/vid1.mp4: 800x480 13 plates, 15.3ms
# video 1/1 (frame 28/285) /content/resources/vid1.mp4: 800x480 14 plates, 15.3ms
# video 1/1 (frame 29/285) /content/resources/vid1.mp4: 800x480 14 plates, 15.3ms
# video 1/1 (frame 30/285) /content/resources/vid1.mp4: 800x480 15 plates, 15.3ms
# video 1/1 (frame 31/285) /content/resources/vid1.mp4: 800x480 19 plates, 15.2ms
# video 1/1 (frame 32/285) /content/resources/vid1.mp4: 800x480 17 plates, 15.3ms
# video 1/1 (frame 33/285) /content/resources/vid1.mp4: 800x480 18 plates, 15.3ms
# video 1/1 (frame 34/285) /content/resources/vid1.mp4: 800x480 18 plates, 15.3ms
# video 1/1 (frame 35/285) /content/resources/vid1.mp4: 800x480 16 plates, 15.3ms
# video 1/1 (frame 36/285) /content/resources/vid1.mp4: 800x480 20 plates, 15.3ms
# video 1/1 (frame 37/285) /content/resources/vid1.mp4: 800x480 16 plates, 15.2ms
# video 1/1 (frame 38/285) /content/resources/vid1.mp4: 800x480 16 plates, 15.3ms
# video 1/1 (frame 39/285) /content/resources/vid1.mp4: 800x480 18 plates, 15.3ms
# video 1/1 (frame 40/285) /content/resources/vid1.mp4: 800x480 19 plates, 15.3ms
# video 1/1 (frame 41/285) /content/resources/vid1.mp4: 800x480 18 plates, 15.3ms
# video 1/1 (frame 42/285) /content/resources/vid1.mp4: 800x480 15 plates, 15.4ms
# video 1/1 (frame 43/285) /content/resources/vid1.mp4: 800x480 15 plates, 15.3ms
# video 1/1 (frame 44/285) /content/resources/vid1.mp4: 800x480 16 plates, 15.3ms
# video 1/1 (frame 45/285) /content/resources/vid1.mp4: 800x480 15 plates, 15.3ms
# video 1/1 (frame 46/285) /content/resources/vid1.mp4: 800x480 18 plates, 15.3ms
# video 1/1 (frame 47/285) /content/resources/vid1.mp4: 800x480 12 plates, 15.3ms
# video 1/1 (frame 48/285) /content/resources/vid1.mp4: 800x480 15 plates, 15.4ms
# video 1/1 (frame 49/285) /content/resources/vid1.mp4: 800x480 17 plates, 15.3ms
# video 1/1 (frame 50/285) /content/resources/vid1.mp4: 800x480 12 plates, 15.2ms
# video 1/1 (frame 51/285) /content/resources/vid1.mp4: 800x480 12 plates, 15.3ms
# video 1/1 (frame 52/285) /content/resources/vid1.mp4: 800x480 14 plates, 15.3ms
# video 1/1 (frame 53/285) /content/resources/vid1.mp4: 800x480 14 plates, 15.2ms
# video 1/1 (frame 54/285) /content/resources/vid1.mp4: 800x480 12 plates, 15.3ms
# video 1/1 (frame 55/285) /content/resources/vid1.mp4: 800x480 12 plates, 15.3ms
# video 1/1 (frame 56/285) /content/resources/vid1.mp4: 800x480 10 plates, 15.3ms
# video 1/1 (frame 57/285) /content/resources/vid1.mp4: 800x480 8 plates, 15.3ms
# video 1/1 (frame 58/285) /content/resources/vid1.mp4: 800x480 9 plates, 15.3ms
# video 1/1 (frame 59/285) /content/resources/vid1.mp4: 800x480 9 plates, 15.3ms
# video 1/1 (frame 60/285) /content/resources/vid1.mp4: 800x480 11 plates, 15.3ms
# video 1/1 (frame 61/285) /content/resources/vid1.mp4: 800x480 12 plates, 15.3ms
# video 1/1 (frame 62/285) /content/resources/vid1.mp4: 800x480 16 plates, 15.3ms
# video 1/1 (frame 63/285) /content/resources/vid1.mp4: 800x480 13 plates, 15.3ms
# video 1/1 (frame 64/285) /content/resources/vid1.mp4: 800x480 12 plates, 15.3ms
# video 1/1 (frame 65/285) /content/resources/vid1.mp4: 800x480 14 plates, 15.3ms
# video 1/1 (frame 66/285) /content/resources/vid1.mp4: 800x480 12 plates, 15.3ms
# video 1/1 (frame 67/285) /content/resources/vid1.mp4: 800x480 15 plates, 15.2ms
# video 1/1 (frame 68/285) /content/resources/vid1.mp4: 800x480 11 plates, 15.3ms
# video 1/1 (frame 69/285) /content/resources/vid1.mp4: 800x480 13 plates, 15.3ms
# video 1/1 (frame 70/285) /content/resources/vid1.mp4: 800x480 15 plates, 15.3ms
# video 1/1 (frame 71/285) /content/resources/vid1.mp4: 800x480 16 plates, 15.3ms
# video 1/1 (frame 72/285) /content/resources/vid1.mp4: 800x480 15 plates, 15.3ms
# video 1/1 (frame 73/285) /content/resources/vid1.mp4: 800x480 13 plates, 15.3ms
# video 1/1 (frame 74/285) /content/resources/vid1.mp4: 800x480 14 plates, 15.3ms
# video 1/1 (frame 75/285) /content/resources/vid1.mp4: 800x480 17 plates, 15.3ms
# video 1/1 (frame 76/285) /content/resources/vid1.mp4: 800x480 19 plates, 15.3ms
# video 1/1 (frame 77/285) /content/resources/vid1.mp4: 800x480 18 plates, 15.3ms
# video 1/1 (frame 78/285) /content/resources/vid1.mp4: 800x480 17 plates, 15.3ms
# video 1/1 (frame 79/285) /content/resources/vid1.mp4: 800x480 17 plates, 15.5ms
# video 1/1 (frame 80/285) /content/resources/vid1.mp4: 800x480 17 plates, 15.6ms
# video 1/1 (frame 81/285) /content/resources/vid1.mp4: 800x480 15 plates, 15.6ms
# video 1/1 (frame 82/285) /content/resources/vid1.mp4: 800x480 16 plates, 15.6ms
# video 1/1 (frame 83/285) /content/resources/vid1.mp4: 800x480 16 plates, 15.6ms
# video 1/1 (frame 84/285) /content/resources/vid1.mp4: 800x480 17 plates, 15.7ms
# video 1/1 (frame 85/285) /content/resources/vid1.mp4: 800x480 17 plates, 15.6ms
# video 1/1 (frame 86/285) /content/resources/vid1.mp4: 800x480 17 plates, 15.6ms
# video 1/1 (frame 87/285) /content/resources/vid1.mp4: 800x480 17 plates, 15.7ms
# video 1/1 (frame 88/285) /content/resources/vid1.mp4: 800x480 16 plates, 15.6ms
# video 1/1 (frame 89/285) /content/resources/vid1.mp4: 800x480 15 plates, 15.3ms
# video 1/1 (frame 90/285) /content/resources/vid1.mp4: 800x480 16 plates, 15.3ms
# video 1/1 (frame 91/285) /content/resources/vid1.mp4: 800x480 18 plates, 15.2ms
# video 1/1 (frame 92/285) /content/resources/vid1.mp4: 800x480 16 plates, 15.3ms
# video 1/1 (frame 93/285) /content/resources/vid1.mp4: 800x480 17 plates, 15.3ms
# video 1/1 (frame 94/285) /content/resources/vid1.mp4: 800x480 19 plates, 15.3ms
# video 1/1 (frame 95/285) /content/resources/vid1.mp4: 800x480 17 plates, 15.3ms
# video 1/1 (frame 96/285) /content/resources/vid1.mp4: 800x480 17 plates, 15.3ms
# video 1/1 (frame 97/285) /content/resources/vid1.mp4: 800x480 19 plates, 15.3ms
# video 1/1 (frame 98/285) /content/resources/vid1.mp4: 800x480 20 plates, 15.3ms
# video 1/1 (frame 99/285) /content/resources/vid1.mp4: 800x480 19 plates, 15.3ms
# video 1/1 (frame 100/285) /content/resources/vid1.mp4: 800x480 18 plates, 15.3ms
# video 1/1 (frame 101/285) /content/resources/vid1.mp4: 800x480 21 plates, 15.3ms
# video 1/1 (frame 102/285) /content/resources/vid1.mp4: 800x480 20 plates, 15.3ms
# video 1/1 (frame 103/285) /content/resources/vid1.mp4: 800x480 19 plates, 15.3ms
# video 1/1 (frame 104/285) /content/resources/vid1.mp4: 800x480 17 plates, 15.3ms
# video 1/1 (frame 105/285) /content/resources/vid1.mp4: 800x480 21 plates, 15.3ms
# video 1/1 (frame 106/285) /content/resources/vid1.mp4: 800x480 20 plates, 15.4ms
# video 1/1 (frame 107/285) /content/resources/vid1.mp4: 800x480 20 plates, 15.3ms
# video 1/1 (frame 108/285) /content/resources/vid1.mp4: 800x480 18 plates, 15.3ms
# video 1/1 (frame 109/285) /content/resources/vid1.mp4: 800x480 19 plates, 15.3ms
# video 1/1 (frame 110/285) /content/resources/vid1.mp4: 800x480 18 plates, 15.3ms
# video 1/1 (frame 111/285) /content/resources/vid1.mp4: 800x480 18 plates, 15.3ms
# video 1/1 (frame 112/285) /content/resources/vid1.mp4: 800x480 18 plates, 15.3ms
# video 1/1 (frame 113/285) /content/resources/vid1.mp4: 800x480 21 plates, 15.3ms
# video 1/1 (frame 114/285) /content/resources/vid1.mp4: 800x480 19 plates, 15.3ms
# video 1/1 (frame 115/285) /content/resources/vid1.mp4: 800x480 19 plates, 15.3ms
# video 1/1 (frame 116/285) /content/resources/vid1.mp4: 800x480 20 plates, 15.3ms
# video 1/1 (frame 117/285) /content/resources/vid1.mp4: 800x480 16 plates, 15.3ms
# video 1/1 (frame 118/285) /content/resources/vid1.mp4: 800x480 15 plates, 15.3ms
# video 1/1 (frame 119/285) /content/resources/vid1.mp4: 800x480 18 plates, 15.3ms
# video 1/1 (frame 120/285) /content/resources/vid1.mp4: 800x480 18 plates, 15.3ms
# video 1/1 (frame 121/285) /content/resources/vid1.mp4: 800x480 20 plates, 15.3ms
# video 1/1 (frame 122/285) /content/resources/vid1.mp4: 800x480 21 plates, 15.3ms
# video 1/1 (frame 123/285) /content/resources/vid1.mp4: 800x480 18 plates, 15.3ms
# video 1/1 (frame 124/285) /content/resources/vid1.mp4: 800x480 22 plates, 15.3ms
# video 1/1 (frame 125/285) /content/resources/vid1.mp4: 800x480 18 plates, 15.3ms
# video 1/1 (frame 126/285) /content/resources/vid1.mp4: 800x480 18 plates, 15.3ms
# video 1/1 (frame 127/285) /content/resources/vid1.mp4: 800x480 17 plates, 15.3ms
# video 1/1 (frame 128/285) /content/resources/vid1.mp4: 800x480 17 plates, 15.3ms
# video 1/1 (frame 129/285) /content/resources/vid1.mp4: 800x480 23 plates, 15.3ms
# video 1/1 (frame 130/285) /content/resources/vid1.mp4: 800x480 19 plates, 15.8ms
# video 1/1 (frame 131/285) /content/resources/vid1.mp4: 800x480 17 plates, 15.8ms
# video 1/1 (frame 132/285) /content/resources/vid1.mp4: 800x480 20 plates, 15.8ms
# video 1/1 (frame 133/285) /content/resources/vid1.mp4: 800x480 20 plates, 15.7ms
# video 1/1 (frame 134/285) /content/resources/vid1.mp4: 800x480 15 plates, 15.8ms
# video 1/1 (frame 135/285) /content/resources/vid1.mp4: 800x480 17 plates, 15.7ms
# video 1/1 (frame 136/285) /content/resources/vid1.mp4: 800x480 21 plates, 15.7ms
# video 1/1 (frame 137/285) /content/resources/vid1.mp4: 800x480 18 plates, 15.8ms
# video 1/1 (frame 138/285) /content/resources/vid1.mp4: 800x480 16 plates, 15.9ms
# video 1/1 (frame 139/285) /content/resources/vid1.mp4: 800x480 15 plates, 15.7ms
# video 1/1 (frame 140/285) /content/resources/vid1.mp4: 800x480 15 plates, 15.7ms
# video 1/1 (frame 141/285) /content/resources/vid1.mp4: 800x480 15 plates, 15.6ms
# video 1/1 (frame 142/285) /content/resources/vid1.mp4: 800x480 19 plates, 17.2ms
# video 1/1 (frame 143/285) /content/resources/vid1.mp4: 800x480 17 plates, 15.7ms
# video 1/1 (frame 144/285) /content/resources/vid1.mp4: 800x480 18 plates, 15.7ms
# video 1/1 (frame 145/285) /content/resources/vid1.mp4: 800x480 19 plates, 15.7ms
# video 1/1 (frame 146/285) /content/resources/vid1.mp4: 800x480 20 plates, 15.7ms
# video 1/1 (frame 147/285) /content/resources/vid1.mp4: 800x480 17 plates, 15.7ms
# video 1/1 (frame 148/285) /content/resources/vid1.mp4: 800x480 18 plates, 15.7ms
# video 1/1 (frame 149/285) /content/resources/vid1.mp4: 800x480 19 plates, 15.7ms
# video 1/1 (frame 150/285) /content/resources/vid1.mp4: 800x480 21 plates, 15.7ms
# video 1/1 (frame 151/285) /content/resources/vid1.mp4: 800x480 19 plates, 15.7ms
# video 1/1 (frame 152/285) /content/resources/vid1.mp4: 800x480 20 plates, 15.7ms
# video 1/1 (frame 153/285) /content/resources/vid1.mp4: 800x480 19 plates, 15.7ms
# video 1/1 (frame 154/285) /content/resources/vid1.mp4: 800x480 20 plates, 15.7ms
# video 1/1 (frame 155/285) /content/resources/vid1.mp4: 800x480 18 plates, 15.7ms
# video 1/1 (frame 156/285) /content/resources/vid1.mp4: 800x480 15 plates, 15.7ms
# video 1/1 (frame 157/285) /content/resources/vid1.mp4: 800x480 18 plates, 17.3ms
# video 1/1 (frame 158/285) /content/resources/vid1.mp4: 800x480 17 plates, 15.7ms
# video 1/1 (frame 159/285) /content/resources/vid1.mp4: 800x480 17 plates, 15.7ms
# video 1/1 (frame 160/285) /content/resources/vid1.mp4: 800x480 19 plates, 15.8ms
# video 1/1 (frame 161/285) /content/resources/vid1.mp4: 800x480 18 plates, 15.7ms
# video 1/1 (frame 162/285) /content/resources/vid1.mp4: 800x480 18 plates, 16.7ms
# video 1/1 (frame 163/285) /content/resources/vid1.mp4: 800x480 18 plates, 15.7ms
# video 1/1 (frame 164/285) /content/resources/vid1.mp4: 800x480 16 plates, 15.7ms
# video 1/1 (frame 165/285) /content/resources/vid1.mp4: 800x480 17 plates, 15.7ms
# video 1/1 (frame 166/285) /content/resources/vid1.mp4: 800x480 18 plates, 15.7ms
# video 1/1 (frame 167/285) /content/resources/vid1.mp4: 800x480 16 plates, 15.7ms
# video 1/1 (frame 168/285) /content/resources/vid1.mp4: 800x480 18 plates, 15.6ms
# video 1/1 (frame 169/285) /content/resources/vid1.mp4: 800x480 17 plates, 15.6ms
# video 1/1 (frame 170/285) /content/resources/vid1.mp4: 800x480 16 plates, 15.7ms
# video 1/1 (frame 171/285) /content/resources/vid1.mp4: 800x480 22 plates, 15.6ms
# video 1/1 (frame 172/285) /content/resources/vid1.mp4: 800x480 16 plates, 15.6ms
# video 1/1 (frame 173/285) /content/resources/vid1.mp4: 800x480 13 plates, 15.7ms
# video 1/1 (frame 174/285) /content/resources/vid1.mp4: 800x480 13 plates, 15.7ms
# video 1/1 (frame 175/285) /content/resources/vid1.mp4: 800x480 13 plates, 15.7ms
# video 1/1 (frame 176/285) /content/resources/vid1.mp4: 800x480 16 plates, 15.6ms
# video 1/1 (frame 177/285) /content/resources/vid1.mp4: 800x480 15 plates, 18.4ms
# video 1/1 (frame 178/285) /content/resources/vid1.mp4: 800x480 15 plates, 15.7ms
# video 1/1 (frame 179/285) /content/resources/vid1.mp4: 800x480 16 plates, 15.7ms
# video 1/1 (frame 180/285) /content/resources/vid1.mp4: 800x480 15 plates, 15.7ms
# video 1/1 (frame 181/285) /content/resources/vid1.mp4: 800x480 14 plates, 15.6ms
# video 1/1 (frame 182/285) /content/resources/vid1.mp4: 800x480 15 plates, 15.6ms
# video 1/1 (frame 183/285) /content/resources/vid1.mp4: 800x480 16 plates, 15.7ms
# video 1/1 (frame 184/285) /content/resources/vid1.mp4: 800x480 13 plates, 15.7ms
# video 1/1 (frame 185/285) /content/resources/vid1.mp4: 800x480 17 plates, 15.6ms
# video 1/1 (frame 186/285) /content/resources/vid1.mp4: 800x480 17 plates, 15.7ms
# video 1/1 (frame 187/285) /content/resources/vid1.mp4: 800x480 17 plates, 15.7ms
# video 1/1 (frame 188/285) /content/resources/vid1.mp4: 800x480 16 plates, 15.7ms
# video 1/1 (frame 189/285) /content/resources/vid1.mp4: 800x480 15 plates, 15.7ms
# video 1/1 (frame 190/285) /content/resources/vid1.mp4: 800x480 15 plates, 15.7ms
# video 1/1 (frame 191/285) /content/resources/vid1.mp4: 800x480 15 plates, 15.6ms
# video 1/1 (frame 192/285) /content/resources/vid1.mp4: 800x480 11 plates, 15.7ms
# video 1/1 (frame 193/285) /content/resources/vid1.mp4: 800x480 12 plates, 15.6ms
# video 1/1 (frame 194/285) /content/resources/vid1.mp4: 800x480 13 plates, 15.7ms
# video 1/1 (frame 195/285) /content/resources/vid1.mp4: 800x480 13 plates, 15.6ms
# video 1/1 (frame 196/285) /content/resources/vid1.mp4: 800x480 15 plates, 15.7ms
# video 1/1 (frame 197/285) /content/resources/vid1.mp4: 800x480 17 plates, 15.3ms
# video 1/1 (frame 198/285) /content/resources/vid1.mp4: 800x480 11 plates, 15.4ms
# video 1/1 (frame 199/285) /content/resources/vid1.mp4: 800x480 15 plates, 15.3ms
# video 1/1 (frame 200/285) /content/resources/vid1.mp4: 800x480 14 plates, 15.3ms
# video 1/1 (frame 201/285) /content/resources/vid1.mp4: 800x480 11 plates, 15.3ms
# video 1/1 (frame 202/285) /content/resources/vid1.mp4: 800x480 11 plates, 15.3ms
# video 1/1 (frame 203/285) /content/resources/vid1.mp4: 800x480 14 plates, 15.4ms
# video 1/1 (frame 204/285) /content/resources/vid1.mp4: 800x480 14 plates, 15.3ms
# video 1/1 (frame 205/285) /content/resources/vid1.mp4: 800x480 10 plates, 15.3ms
# video 1/1 (frame 206/285) /content/resources/vid1.mp4: 800x480 11 plates, 15.3ms
# video 1/1 (frame 207/285) /content/resources/vid1.mp4: 800x480 9 plates, 15.3ms
# video 1/1 (frame 208/285) /content/resources/vid1.mp4: 800x480 9 plates, 15.3ms
# video 1/1 (frame 209/285) /content/resources/vid1.mp4: 800x480 10 plates, 15.3ms
# video 1/1 (frame 210/285) /content/resources/vid1.mp4: 800x480 10 plates, 15.3ms
# video 1/1 (frame 211/285) /content/resources/vid1.mp4: 800x480 10 plates, 15.3ms
# video 1/1 (frame 212/285) /content/resources/vid1.mp4: 800x480 12 plates, 15.3ms
# video 1/1 (frame 213/285) /content/resources/vid1.mp4: 800x480 11 plates, 15.3ms
# video 1/1 (frame 214/285) /content/resources/vid1.mp4: 800x480 10 plates, 15.3ms
# video 1/1 (frame 215/285) /content/resources/vid1.mp4: 800x480 9 plates, 15.3ms
# video 1/1 (frame 216/285) /content/resources/vid1.mp4: 800x480 9 plates, 15.3ms
# video 1/1 (frame 217/285) /content/resources/vid1.mp4: 800x480 10 plates, 15.3ms
# video 1/1 (frame 218/285) /content/resources/vid1.mp4: 800x480 11 plates, 15.3ms
# video 1/1 (frame 219/285) /content/resources/vid1.mp4: 800x480 8 plates, 15.3ms
# video 1/1 (frame 220/285) /content/resources/vid1.mp4: 800x480 10 plates, 15.3ms
# video 1/1 (frame 221/285) /content/resources/vid1.mp4: 800x480 10 plates, 15.3ms
# video 1/1 (frame 222/285) /content/resources/vid1.mp4: 800x480 10 plates, 15.4ms
# video 1/1 (frame 223/285) /content/resources/vid1.mp4: 800x480 9 plates, 15.3ms
# video 1/1 (frame 224/285) /content/resources/vid1.mp4: 800x480 9 plates, 15.4ms
# video 1/1 (frame 225/285) /content/resources/vid1.mp4: 800x480 8 plates, 15.4ms
# video 1/1 (frame 226/285) /content/resources/vid1.mp4: 800x480 9 plates, 15.3ms
# video 1/1 (frame 227/285) /content/resources/vid1.mp4: 800x480 9 plates, 15.3ms
# video 1/1 (frame 228/285) /content/resources/vid1.mp4: 800x480 9 plates, 15.3ms
# video 1/1 (frame 229/285) /content/resources/vid1.mp4: 800x480 8 plates, 15.4ms
# video 1/1 (frame 230/285) /content/resources/vid1.mp4: 800x480 8 plates, 15.3ms
# video 1/1 (frame 231/285) /content/resources/vid1.mp4: 800x480 9 plates, 15.3ms
# video 1/1 (frame 232/285) /content/resources/vid1.mp4: 800x480 9 plates, 15.4ms
# video 1/1 (frame 233/285) /content/resources/vid1.mp4: 800x480 9 plates, 15.3ms
# video 1/1 (frame 234/285) /content/resources/vid1.mp4: 800x480 8 plates, 15.3ms
# video 1/1 (frame 235/285) /content/resources/vid1.mp4: 800x480 8 plates, 15.3ms
# video 1/1 (frame 236/285) /content/resources/vid1.mp4: 800x480 8 plates, 15.3ms
# video 1/1 (frame 237/285) /content/resources/vid1.mp4: 800x480 8 plates, 15.3ms
# video 1/1 (frame 238/285) /content/resources/vid1.mp4: 800x480 7 plates, 15.4ms
# video 1/1 (frame 239/285) /content/resources/vid1.mp4: 800x480 7 plates, 15.3ms
# video 1/1 (frame 240/285) /content/resources/vid1.mp4: 800x480 7 plates, 15.3ms
# video 1/1 (frame 241/285) /content/resources/vid1.mp4: 800x480 8 plates, 15.3ms
# video 1/1 (frame 242/285) /content/resources/vid1.mp4: 800x480 7 plates, 15.3ms
# video 1/1 (frame 243/285) /content/resources/vid1.mp4: 800x480 7 plates, 15.3ms
# video 1/1 (frame 244/285) /content/resources/vid1.mp4: 800x480 8 plates, 15.3ms
# video 1/1 (frame 245/285) /content/resources/vid1.mp4: 800x480 7 plates, 15.3ms
# video 1/1 (frame 246/285) /content/resources/vid1.mp4: 800x480 7 plates, 15.4ms
# video 1/1 (frame 247/285) /content/resources/vid1.mp4: 800x480 6 plates, 15.3ms
# video 1/1 (frame 248/285) /content/resources/vid1.mp4: 800x480 6 plates, 15.3ms
# video 1/1 (frame 249/285) /content/resources/vid1.mp4: 800x480 6 plates, 15.3ms
# video 1/1 (frame 250/285) /content/resources/vid1.mp4: 800x480 6 plates, 15.3ms
# video 1/1 (frame 251/285) /content/resources/vid1.mp4: 800x480 6 plates, 15.3ms
# video 1/1 (frame 252/285) /content/resources/vid1.mp4: 800x480 5 plates, 15.3ms
# video 1/1 (frame 253/285) /content/resources/vid1.mp4: 800x480 6 plates, 15.3ms
# video 1/1 (frame 254/285) /content/resources/vid1.mp4: 800x480 6 plates, 15.3ms
# video 1/1 (frame 255/285) /content/resources/vid1.mp4: 800x480 5 plates, 15.3ms
# video 1/1 (frame 256/285) /content/resources/vid1.mp4: 800x480 4 plates, 15.3ms
# video 1/1 (frame 257/285) /content/resources/vid1.mp4: 800x480 5 plates, 15.3ms
# video 1/1 (frame 258/285) /content/resources/vid1.mp4: 800x480 5 plates, 15.4ms
# video 1/1 (frame 259/285) /content/resources/vid1.mp4: 800x480 5 plates, 15.3ms
# video 1/1 (frame 260/285) /content/resources/vid1.mp4: 800x480 5 plates, 15.3ms
# video 1/1 (frame 261/285) /content/resources/vid1.mp4: 800x480 5 plates, 15.3ms
# video 1/1 (frame 262/285) /content/resources/vid1.mp4: 800x480 4 plates, 15.3ms
# video 1/1 (frame 263/285) /content/resources/vid1.mp4: 800x480 7 plates, 15.3ms
# video 1/1 (frame 264/285) /content/resources/vid1.mp4: 800x480 3 plates, 15.3ms
# video 1/1 (frame 265/285) /content/resources/vid1.mp4: 800x480 6 plates, 15.3ms
# video 1/1 (frame 266/285) /content/resources/vid1.mp4: 800x480 6 plates, 15.3ms
# video 1/1 (frame 267/285) /content/resources/vid1.mp4: 800x480 7 plates, 15.3ms
# video 1/1 (frame 268/285) /content/resources/vid1.mp4: 800x480 3 plates, 15.3ms
# video 1/1 (frame 269/285) /content/resources/vid1.mp4: 800x480 4 plates, 15.3ms
# video 1/1 (frame 270/285) /content/resources/vid1.mp4: 800x480 3 plates, 15.3ms
# video 1/1 (frame 271/285) /content/resources/vid1.mp4: 800x480 4 plates, 15.3ms
# video 1/1 (frame 272/285) /content/resources/vid1.mp4: 800x480 3 plates, 15.3ms
# video 1/1 (frame 273/285) /content/resources/vid1.mp4: 800x480 2 plates, 15.3ms
# video 1/1 (frame 274/285) /content/resources/vid1.mp4: 800x480 2 plates, 15.0ms
# video 1/1 (frame 275/285) /content/resources/vid1.mp4: 800x480 3 plates, 14.4ms
# video 1/1 (frame 276/285) /content/resources/vid1.mp4: 800x480 2 plates, 18.1ms
# video 1/1 (frame 277/285) /content/resources/vid1.mp4: 800x480 2 plates, 14.4ms
# video 1/1 (frame 278/285) /content/resources/vid1.mp4: 800x480 3 plates, 14.4ms
# video 1/1 (frame 279/285) /content/resources/vid1.mp4: 800x480 3 plates, 14.4ms
# video 1/1 (frame 280/285) /content/resources/vid1.mp4: 800x480 3 plates, 14.4ms
# video 1/1 (frame 281/285) /content/resources/vid1.mp4: 800x480 1 plate, 14.4ms
# video 1/1 (frame 282/285) /content/resources/vid1.mp4: 800x480 2 plates, 14.4ms
# Speed: 5.0ms preprocess, 15.5ms inference, 1.9ms postprocess per image at shape (1, 3, 800, 480)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# %cd {HOME}
Image(filename='runs/detect/predict/dog.jpeg', height=600)

# %% [markdown]
# ### 🐍 Python SDK
#
# The simplest way of simply using YOLOv8 directly in a Python environment.

# %%
model = YOLO(f'{HOME}/yolov8n.pt')
results = model.predict(source='https://media.roboflow.com/notebooks/examples/dog.jpeg', conf=0.25)

# %%
results[0].boxes.xyxy

# %%
results[0].boxes.conf

# %%
results[0].boxes.cls

# %% [markdown]
# ## Roboflow Universe
#
# Need data for your project? Before spending time on annotating, check out Roboflow Universe, a repository of more than 110,000 open-source datasets that you can use in your projects. You'll find datasets containing everything from annotated cracks in concrete to plant images with disease annotations.
#
#
# [![Roboflow Universe](https://media.roboflow.com/notebooks/template/uni-banner-frame.png?ik-sdk-version=javascript-1.4.3&updatedAt=1672878480290)](https://universe.roboflow.com/)

# %% [markdown]
# ## Preparing a custom dataset
#
# Building a custom dataset can be a painful process. It might take dozens or even hundreds of hours to collect images, label them, and export them in the proper format. Fortunately, Roboflow makes this process as straightforward and fast as possible. Let me show you how!
#
# ### Step 1: Creating project
#
# Before you start, you need to create a Roboflow [account](https://app.roboflow.com/login). Once you do that, you can create a new project in the Roboflow [dashboard](https://app.roboflow.com/). Keep in mind to choose the right project type. In our case, Object Detection.
#
# <div align="center">
#   <img
#     width="640"
#     src="https://media.roboflow.com/preparing-custom-dataset-example/creating-project.gif?ik-sdk-version=javascript-1.4.3&updatedAt=1672929799852"
#   >
# </div>
#
# ### Step 2: Uploading images
#
# Next, add the data to your newly created project. You can do it via API or through our [web interface](https://docs.roboflow.com/adding-data/object-detection).
#
# If you drag and drop a directory with a dataset in a [supported format](https://roboflow.com/formats), the Roboflow dashboard will automatically read the images and annotations together.
#
# <div align="center">
#   <img
#     width="640"
#     src="https://media.roboflow.com/preparing-custom-dataset-example/uploading-images.gif?ik-sdk-version=javascript-1.4.3&updatedAt=1672929808290"
#   >
# </div>
#
# ### Step 3: Labeling
#
# If you only have images, you can label them in [Roboflow Annotate](https://docs.roboflow.com/annotate).
#
# <div align="center">
#   <img
#     width="640"
#     src="https://user-images.githubusercontent.com/26109316/210901980-04861efd-dfc0-4a01-9373-13a36b5e1df4.gif"
#   >
# </div>
#
# ### Step 4: Generate new dataset version
#
# Now that we have our images and annotations added, we can Generate a Dataset Version. When Generating a Version, you may elect to add preprocessing and augmentations. This step is completely optional, however, it can allow you to significantly improve the robustness of your model.
#
# <div align="center">
#   <img
#     width="640"
#     src="https://media.roboflow.com/preparing-custom-dataset-example/generate-new-version.gif?ik-sdk-version=javascript-1.4.3&updatedAt=1673003597834"
#   >
# </div>
#
# ### Step 5: Exporting dataset
#
# Once the dataset version is generated, we have a hosted dataset we can load directly into our notebook for easy training. Click `Export` and select the `YOLO v8` dataset format. (Formerly, we used to use `Yolov5`, as the gif shows)
#
# <div align="center">
#   <img
#     width="640"
#     src="https://media.roboflow.com/preparing-custom-dataset-example/export.gif?ik-sdk-version=javascript-1.4.3&updatedAt=1672943313709"
#   >
# </div>

# %% [markdown]
# 🟢 Tip: The examples below work even if you use our non-custom model. However, you won't be able to deploy it to Roboflow. To do that, create a custom dataset as described below or fork (copy) one into your workspace from Universe.

# %%
# !mkdir -p {HOME}
# %cd {HOME}

# !pip install roboflow==1.1.48 --quiet

import roboflow

roboflow.login()

rf = roboflow.Roboflow()

project = rf.workspace("model-examples").project("football-players-obj-detection")
dataset = project.version(2).download("yolov8")
# Out:
# /content
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.3/80.3 kB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 16.1 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tobler 0.13.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# visit https://app.roboflow.com/auth-cli to get your authentication token.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1016811135.py in <cell line: 0>()
#       6 import roboflow
#       7
# ----> 8 roboflow.login()
#       9
#      10 rf = roboflow.Roboflow()
#
# /usr/local/lib/python3.12/dist-packages/roboflow/__init__.py in login(workspace, force)
#      84         write_line("visit " + APP_URL + "/auth-cli/?workspace=" + workspace + " to get your authentication token.")
#      85
# ---> 86     token = getpass("Paste the authentication token here: ")
#      87
#      88     r_login = requests.get(APP_URL + "/query/cliAuthToken/" + token)
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in getpass(self, prompt, stream)
#    1157                 stacklevel=2,
#    1158             )
# -> 1159         return self._input_request(
#    1160             prompt,
#    1161             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# ## Custom Training

# %%
import os
if not os.path.exists("./dataset.zip"):
  # !cp {HOME}/dataset.zip .
# !unzip -q ./dataset.zip
# Out:
# replace dataset/data.yaml? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov8s.pt data=/content/datasets/dataset/data.yaml epochs=25 imgsz=800 plots=True
# Out:
# /content
# New https://pypi.org/project/ultralytics/8.4.9 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.103 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: task=detect, mode=train, model=yolov8s.pt, data=/content/datasets/dataset/data.yaml, epochs=25, time=None, patience=100, batch=16, imgsz=800, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train4, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train4
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100% 755k/755k [00:00<00:00, 27.8MB/s]
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1770014706.886522    3514 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1770014706.892403    3514 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1770014706.907194    3514 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1770014706.907219    3514 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1770014706.907223    3514 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1770014706.907226    3514 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  22        [15, 18, 21]  1   2116435  ultralytics.nn.modules.head.Detect           [1, [128, 256, 512]]
# Model summary: 225 layers, 11,135,987 parameters, 11,135,971 gradients, 28.6 GFLOPs
#
# Transferred 349/355 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train4', view at http://localhost:6006/
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8n.pt to 'yolov8n.pt'...
# 100% 6.25M/6.25M [00:00<00:00, 121MB/s]
# AMP: checks passed ✅
# train: Scanning /content/datasets/dataset/labels/train... 15 images, 0 backgrounds, 0 corrupt: 100% 15/15 [00:00<00:00, 2159.27it/s]
# train: New cache created: /content/datasets/dataset/labels/train.cache
# /usr/local/lib/python3.12/dist-packages/ultralytics/data/augment.py:1837: UserWarning: Argument(s) 'quality_lower' are not valid for transform ImageCompression
#   A.ImageCompression(quality_lower=75, p=0.0),
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Scanning /content/datasets/dataset/labels/val... 4 images, 0 backgrounds, 0 corrupt: 100% 4/4 [00:00<00:00, 353.84it/s]
# val: New cache created: /content/datasets/dataset/labels/val.cache
# Plotting labels to runs/detect/train4/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 800 train, 800 val
# Using 2 dataloader workers
# Logging results to runs/detect/train4
# Starting training for 25 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/25      6.09G      2.324      3.611        1.8        237        800: 100% 1/1 [00:01<00:00,  1.53s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:01<00:00,  1.30s/it]
#                    all          4         44      0.386      0.343      0.274      0.104
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/25      5.55G      2.255      3.538      2.043        131        800: 100% 1/1 [00:00<00:00,  2.23it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  8.79it/s]
#                    all          4         44      0.419      0.361      0.317       0.11
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/25      5.58G      2.298      3.277       1.84        255        800: 100% 1/1 [00:00<00:00,  2.53it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  5.63it/s]
#                    all          4         44      0.424      0.351       0.32       0.11
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/25      5.51G      2.184      2.894      1.782        251        800: 100% 1/1 [00:00<00:00,  2.23it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  7.57it/s]
#                    all          4         44      0.418      0.341      0.321      0.111
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/25      5.52G      2.335       3.28      2.034        203        800: 100% 1/1 [00:00<00:00,  2.57it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00, 16.95it/s]
#                    all          4         44        0.4      0.341       0.32      0.111
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/25      5.49G      2.365      3.423      1.974        181        800: 100% 1/1 [00:00<00:00,  2.58it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00, 11.63it/s]
#                    all          4         44      0.405      0.341      0.315      0.107
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/25      5.65G      2.245      3.302      2.032        160        800: 100% 1/1 [00:00<00:00,  2.07it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00, 19.53it/s]
#                    all          4         44      0.891      0.773      0.768      0.328
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/25      5.62G      1.981      1.735       1.66        210        800: 100% 1/1 [00:00<00:00,  2.47it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00, 15.38it/s]
#                    all          4         44      0.658      0.841       0.81      0.358
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/25      5.63G      2.098      1.373      1.658        232        800: 100% 1/1 [00:00<00:00,  2.50it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00, 18.98it/s]
#                    all          4         44      0.762      0.795      0.738      0.316
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/25      5.61G      1.995      1.404      1.703        236        800: 100% 1/1 [00:00<00:00,  2.52it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00, 15.98it/s]
#                    all          4         44      0.789      0.818      0.764      0.345
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/25      5.64G      1.977      1.224      1.584        234        800: 100% 1/1 [00:00<00:00,  2.45it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00, 19.61it/s]
#                    all          4         44      0.871      0.795      0.799      0.332
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/25      5.74G      2.004      1.389      1.658        175        800: 100% 1/1 [00:00<00:00,  2.52it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  9.48it/s]
#                    all          4         44      0.811       0.75      0.798      0.329
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/25       5.6G      1.984      1.355      1.583        170        800: 100% 1/1 [00:00<00:00,  2.37it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  9.33it/s]
#                    all          4         44      0.848      0.761      0.837       0.34
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/25      5.61G      2.014      1.212      1.507        200        800: 100% 1/1 [00:00<00:00,  2.49it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00, 17.88it/s]
#                    all          4         44      0.858      0.864      0.907      0.393
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/25      6.12G      1.886      1.173      1.523        168        800: 100% 1/1 [00:00<00:00,  2.50it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00, 11.98it/s]
#                    all          4         44      0.906      0.881      0.918      0.413
# Closing dataloader mosaic
# /usr/local/lib/python3.12/dist-packages/ultralytics/data/augment.py:1837: UserWarning: Argument(s) 'quality_lower' are not valid for transform ImageCompression
#   A.ImageCompression(quality_lower=75, p=0.0),
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/25      5.71G      1.987      1.444      1.528        113        800: 100% 1/1 [00:01<00:00,  1.29s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  5.85it/s]
#                    all          4         44      0.882      0.886      0.918      0.405
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/25      5.73G      1.935      1.288      1.573        113        800: 100% 1/1 [00:00<00:00,  2.49it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  6.37it/s]
#                    all          4         44      0.941      0.818       0.91      0.411
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/25       5.7G       1.88      1.255       1.55        112        800: 100% 1/1 [00:00<00:00,  2.76it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  7.45it/s]
#                    all          4         44      0.941      0.818       0.91      0.411
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/25      5.76G      1.883      1.347      1.448        112        800: 100% 1/1 [00:00<00:00,  2.26it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  7.01it/s]
#                    all          4         44      0.972      0.795      0.917      0.432
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/25       5.7G      1.882        1.3      1.493        113        800: 100% 1/1 [00:00<00:00,  2.44it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  8.57it/s]
#                    all          4         44      0.972      0.795      0.917      0.432
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/25      5.74G      1.777      1.224      1.423        110        800: 100% 1/1 [00:00<00:00,  2.53it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00, 16.96it/s]
#                    all          4         44      0.904      0.853      0.924      0.441
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/25       5.7G      1.781      1.211      1.372        112        800: 100% 1/1 [00:00<00:00,  2.78it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00, 13.68it/s]
#                    all          4         44      0.904      0.853      0.924      0.441
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/25      5.74G      1.792      1.126      1.452        111        800: 100% 1/1 [00:00<00:00,  2.41it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00, 18.65it/s]
#                    all          4         44      0.906      0.872      0.929       0.45
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/25       5.7G      1.837      1.179      1.376        113        800: 100% 1/1 [00:00<00:00,  2.77it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00, 16.20it/s]
#                    all          4         44      0.906      0.872      0.929       0.45
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/25      5.76G      1.856      1.252      1.401        112        800: 100% 1/1 [00:00<00:00,  2.56it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00, 10.04it/s]
#                    all          4         44      0.868      0.841      0.902      0.438
#
# 25 epochs completed in 0.013 hours.
# Optimizer stripped from runs/detect/train4/weights/last.pt, 22.5MB
# Optimizer stripped from runs/detect/train4/weights/best.pt, 22.5MB
#
# Validating runs/detect/train4/weights/best.pt...
# Ultralytics YOLOv8.2.103 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 168 layers, 11,125,971 parameters, 0 gradients, 28.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00, 13.74it/s]
#                    all          4         44      0.906      0.872      0.929       0.45
# Speed: 0.2ms preprocess, 3.7ms inference, 0.0ms loss, 1.9ms postprocess per image
# Results saved to runs/detect/train4
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train4/confusion_matrix.png', width=600)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train4/results.png', width=600)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train4/val_batch0_pred.jpg', width=600)
# Out:
# /content

# %% [markdown]
# ## Validate Custom Model

# %%
# %cd {HOME}

# !yolo task=detect mode=val model={HOME}/runs/detect/train4/weights/best.pt data=/content/datasets/dataset/data.yaml
# Out:
# /content
# Ultralytics YOLOv8.2.103 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 168 layers, 11,125,971 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning /content/datasets/dataset/labels/val.cache... 4 images, 0 backgrounds, 0 corrupt: 100% 4/4 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  3.10it/s]
#                    all          4         44      0.906      0.872      0.929      0.448
# Speed: 0.3ms preprocess, 27.5ms inference, 0.0ms loss, 23.4ms postprocess per image
# Results saved to runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %% [markdown]
# ## Inference with Custom Model

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model={HOME}/runs/detect/train4/weights/best.pt conf=0.25 source=/content/datasets/dataset/test/images save=True
# Out:
# /content
# Ultralytics YOLOv8.2.103 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 168 layers, 11,125,971 parameters, 0 gradients, 28.4 GFLOPs
#
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#              ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/cfg/__init__.py", line 831, in entrypoint
#     getattr(model, mode)(**overrides)  # default args from model
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py", line 555, in predict
#     return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/engine/predictor.py", line 183, in predict_cli
#     for _ in gen:  # sourcery skip: remove-empty-nested-block, noqa
#              ^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/_contextlib.py", line 38, in generator_context
#     response = gen.send(None)
#                ^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/engine/predictor.py", line 226, in stream_inference
#     self.setup_source(source if source is not None else self.args.source)
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/engine/predictor.py", line 198, in setup_source
#     self.dataset = load_inference_source(
#                    ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/data/build.py", line 202, in load_inference_source
#     dataset = LoadImagesAndVideos(source, batch=batch, vid_stride=vid_stride)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/data/loaders.py", line 292, in __init__
#     raise FileNotFoundError(f"{p} does not exist")
# FileNotFoundError: /content/datasets/dataset/test/images does not exist

# %% [markdown]
# **NOTE:** Let's take a look at few results.

# %%
import glob
from IPython.display import Image, display

# Define the base path where the folders are located
base_path = '/content/runs/detect/'

# List all directories that start with 'predict' in the base path
subfolders = [os.path.join(base_path, d) for d in os.listdir(base_path)
              if os.path.isdir(os.path.join(base_path, d)) and d.startswith('predict')]

# Find the latest folder by modification time
latest_folder = max(subfolders, key=os.path.getmtime)

image_paths = glob.glob(f'{latest_folder}/*.jpg')[:3]

# Display each image
for image_path in image_paths:
    display(Image(filename=image_path, width=600))
    print("\n")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-4201139547.py in <cell line: 0>()
#      10
#      11 # Find the latest folder by modification time
# ---> 12 latest_folder = max(subfolders, key=os.path.getmtime)
#      13
#      14 image_paths = glob.glob(f'{latest_folder}/*.jpg')[:3]
#
# ValueError: max() iterable argument is empty

# %% [markdown]
# ## Deploy model on Roboflow
#
# Once you have finished training your YOLOv8 model, you’ll have a set of trained weights ready for use. These weights will be in the `/runs/detect/train/weights/best.pt` folder of your project. You can upload your model weights to Roboflow Deploy to use your trained weights on our infinitely scalable infrastructure.
#
# The `.deploy()` function in the [Roboflow pip package](https://docs.roboflow.com/python) now supports uploading YOLOv8 weights.
#
# To upload model weights, add the following code to the “Inference with Custom Model” section in the aforementioned notebook:

# %%
project.version(dataset.version).deploy(model_type="yolov8", model_path=f"{HOME}/runs/detect/train/")

# %% [markdown]
# Follow the links above to check if the upload succeeded. It may take a couple of minutes until the model is visible to the `roboflow` SDK.

# %%
# Run inference on your model on a persistent, auto-scaling, cloud API

# Load model
model = project.version(dataset.version).model
assert model, "Model deployment is still loading"

# Choose a random test image
import os, random
test_set_loc = dataset.location + "/test/images/"
random_test_image = random.choice(os.listdir(test_set_loc))
print("running inference on " + random_test_image)

pred = model.predict(test_set_loc + random_test_image, confidence=40, overlap=30).json()
pred

# %% [markdown]
# # Deploy Your Model to the Edge
#
# In addition to using the Roboflow hosted API for deployment, you can use [Roboflow Inference](https://inference.roboflow.com), an open source inference solution that has powered millions of API calls in production environments. Inference works with CPU and GPU, giving you immediate access to a range of devices, from the NVIDIA Jetson to TRT-compatible devices to ARM CPU devices.
#
# With Roboflow Inference, you can self-host and deploy your model on-device. You can deploy applications using the [Inference Docker containers](https://inference.roboflow.com/quickstart/docker/) or the pip package.
#
# For example, to install Inference on a device with an NVIDIA GPU, we can use:
#
# ```
# docker pull roboflow/roboflow-inference-server-gpu
# ```
#
# Then we can run inference via HTTP:
#
# ```python
# import requests
#
# workspace_id = ""
# model_id = ""
# image_url = ""
# confidence = 0.75
# api_key = ""
#
# infer_payload = {
#     "image": {
#         "type": "url",
#         "value": image_url,
#     },
#     "confidence": confidence,
#     "iou_threshold": iou_thresh,
#     "api_key": api_key,
# }
# res = requests.post(
#     f"http://localhost:9001/{workspace_id}/{model_id}",
#     json=infer_object_detection_payload,
# )
#
# predictions = res.json()
# ```
#
# Above, set your Roboflow workspace ID, model ID, and API key.
#
# - [Find your workspace and model ID](https://docs.roboflow.com/api-reference/workspace-and-project-ids?ref=blog.roboflow.com)
# - [Find your API key](https://docs.roboflow.com/api-reference/authentication?ref=blog.roboflow.com#retrieve-an-api-key)
#
# Also, set the URL of an image on which you want to run inference. This can be a local file.
#
# _To use your YOLOv5 model commercially with Inference, you will need a Roboflow Enterprise license, through which you gain a pass-through license for using YOLOv5. An enterprise license also grants you access to features like advanced device management, multi-model containers, auto-batch inference, and more._

# %% [markdown]
# ## 🏆 Congratulations
#
# ### Learning Resources
#
# Roboflow has produced many resources that you may find interesting as you advance your knowledge of computer vision:
#
# - [Roboflow Notebooks](https://github.com/roboflow/notebooks): A repository of over 20 notebooks that walk through how to train custom models with a range of model types, from YOLOv7 to SegFormer.
# - [Roboflow YouTube](https://www.youtube.com/c/Roboflow): Our library of videos featuring deep dives into the latest in computer vision, detailed tutorials that accompany our notebooks, and more.
# - [Roboflow Discuss](https://discuss.roboflow.com/): Have a question about how to do something on Roboflow? Ask your question on our discussion forum.
# - [Roboflow Models](https://roboflow.com): Learn about state-of-the-art models and their performance. Find links and tutorials to guide your learning.
#
# ### Convert data formats
#
# Roboflow provides free utilities to convert data between dozens of popular computer vision formats. Check out [Roboflow Formats](https://roboflow.com/formats) to find tutorials on how to convert data between formats in a few clicks.
#
# ### Connect computer vision to your project logic
#
# [Roboflow Templates](https://roboflow.com/templates) is a public gallery of code snippets that you can use to connect computer vision to your project logic. Code snippets range from sending emails after inference to measuring object distance between detections.
